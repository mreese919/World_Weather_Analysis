# %%
# Import the dependencies.
import pandas as pd
import gmaps
import requests
# Import the API key.
from config import g_key

# %%
# Store the CSV you saved created in part one into a DataFrame.
city_data_df = pd.read_csv("resources/cities.csv")
city_data_df.head()
# Out:
#    City_ID         City Country                 Date      Lat       Lng  \
# 0        0      Kavieng      PG  2021-04-02 21:39:08  -2.5744  150.7967
# 1        1  Clyde River      CA  2021-04-02 21:37:16  70.4692  -68.5914
# 2        2         Hofn      IS  2021-04-02 21:39:09  64.2539  -15.2082
# 3        3    Sinnamary      GF  2021-04-02 21:39:09   5.3833  -52.9500
# 4        4   Nikolskoye      RU  2021-04-02 21:39:10  59.7035   30.7861
#
#    Max Temp  Humidity  Cloudiness  Wind Speed
# 0     84.00        76          99        9.89
# 1     -7.60        71           1       10.36
# 2     43.47        59           2        8.61
# 3     75.24        93         100        8.41
# 4     36.00        93           0        3.27

# %%
city_data_df.dtypes
# Out:
# City_ID         int64
# City           object
# Country        object
# Date           object
# Lat           float64
# Lng           float64
# Max Temp      float64
# Humidity        int64
# Cloudiness      int64
# Wind Speed    float64
# dtype: object

# %%
# Configure gmaps to use your Google API key.
gmaps.configure(api_key=g_key)

# %%
# Get the maximum temperature.
max_temp = city_data_df["Max Temp"]
temps = []
for temp in max_temp:
    temps.append(max(temp, 0))

# %%
# Heatmap of temperature
# Get the latitude and longitude.
locations = city_data_df[["Lat", "Lng"]]
# Get the maximum temperature.
max_temp = city_data_df["Max Temp"]
# Assign the figure variable.
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=2.5)
# Assign the heatmap variable.
heat_layer = gmaps.heatmap_layer(locations, weights=temps, dissipating=False, max_intensity=300, point_radius=4)
# Add the heatmap layer.
fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Heatmap of percent humidity
locations = city_data_df[["Lat", "Lng"]]
humidity = city_data_df["Humidity"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=2.5)
heat_layer = gmaps.heatmap_layer(locations, weights=humidity, dissipating=False, max_intensity=300, point_radius=4)

fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Heatmap of Clouds
locations = city_data_df[["Lat", "Lng"]]
clouds = city_data_df["Cloudiness"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=2.5)
heat_layer = gmaps.heatmap_layer(locations, weights=clouds, dissipating=False, max_intensity=300, point_radius=4)

fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Heatmap of Clouds
locations = city_data_df[["Lat", "Lng"]]
wind = city_data_df["Wind Speed"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=2.5)
heat_layer = gmaps.heatmap_layer(locations, weights=wind, dissipating=False, max_intensity=300, point_radius=4)

fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Ask the customer to add a minimum and maximum temperature value.
min_temp = float(input("What is the minimum temperature you would like for your trip? "))
max_temp = float(input("What is the maximum temperature you would like for your trip? "))
# Out:
# What is the minimum temperature you would like for your trip? 75
# What is the maximum temperature you would like for your trip? 90

# %%
# Filter the dataset to find the cities that fit the criteria.
preferred_cities_df = city_data_df.loc[(city_data_df["Max Temp"] <= max_temp) & \
                                       (city_data_df["Max Temp"] >= min_temp)]
preferred_cities_df.head(10)
# Out:
#     City_ID            City Country                 Date      Lat       Lng  \
# 0         0         Kavieng      PG  2021-04-02 21:39:08  -2.5744  150.7967
# 3         3       Sinnamary      GF  2021-04-02 21:39:09   5.3833  -52.9500
# 7         7           Alofi      NU  2021-04-02 21:39:10 -19.0595 -169.9187
# 11       11       Caravelas      BR  2021-04-02 21:39:12 -17.7125  -39.2481
# 12       12       Carnarvon      AU  2021-04-02 21:39:12 -24.8667  113.6333
# 15       15  Cabo San Lucas      MX  2021-04-02 21:39:13  22.8909 -109.9124
# 17       17           Pisco      PE  2021-04-02 21:34:38 -13.7000  -76.2167
# 18       18       Mahebourg      MU  2021-04-02 21:39:14 -20.4081   57.7000
# 19       19      Georgetown      MY  2021-04-02 21:39:14   5.4112  100.3354
# 25       25         Pizarro      CO  2021-04-02 21:39:16   4.9533  -77.3660
#
#     Max Temp  Humidity  Cloudiness  Wind Speed
# 0      84.00        76          99        9.89
# 3      75.24        93         100        8.41
# 7      84.20        70          38        9.22
# 11     77.49        82          37        6.22
# 12     77.00        94          33       10.36
# 15     88.00        29          75        2.30
# 17     75.20        69           0        8.05
# 18     75.20       100          40        3.44
# 19     82.40        94          20        3.44
# 25     81.18        79          98        6.08

# %%
preferred_cities_df.count()
# Out:
# City_ID       164
# City          164
# Country       164
# Date          164
# Lat           164
# Lng           164
# Max Temp      164
# Humidity      164
# Cloudiness    164
# Wind Speed    164
# dtype: int64

# %%
# Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
hotel_df = preferred_cities_df[["City", "Country", "Max Temp", "Lat", "Lng"]].copy()
hotel_df["Hotel Name"] = ""
hotel_df.head(10)
# Out:
#               City Country  Max Temp      Lat       Lng Hotel Name
# 0          Kavieng      PG     84.00  -2.5744  150.7967
# 3        Sinnamary      GF     75.24   5.3833  -52.9500
# 7            Alofi      NU     84.20 -19.0595 -169.9187
# 11       Caravelas      BR     77.49 -17.7125  -39.2481
# 12       Carnarvon      AU     77.00 -24.8667  113.6333
# 15  Cabo San Lucas      MX     88.00  22.8909 -109.9124
# 17           Pisco      PE     75.20 -13.7000  -76.2167
# 18       Mahebourg      MU     75.20 -20.4081   57.7000
# 19      Georgetown      MY     82.40   5.4112  100.3354
# 25         Pizarro      CO     81.18   4.9533  -77.3660

# %%
# Set parameters to search for a hotel.
params = {
    "radius": 5000,
    "type": "lodging",
    "key": g_key
}

# %%
# Dependencies and Setup
import requests
import gmaps

# Import API key
from config import g_key

# %%
# Set the parameters to search for a hotel in Paris.
params = {
    "radius": 5000,
    "types": "lodging",
    "key": g_key,
    "location": "48.8566, 2.3522"}
# Use base URL to search for hotels in Paris.
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
# Make request and get the JSON data from the search.
hotels = requests.get(base_url, params=params).json()

hotels
# Out:
# {'html_attributions': [],
#  'next_page_token': 'ATtYBwLv_4l8uxZQUY0AxF3atacsNbRo2tRNnxZDL8zAx3Ng7cqsTAozC1Fpak1GCPmhCpjhPWGnHSEMZHMyycOu2UGdDcELm_mZSke7bdtP5o3FLXsn2HI5fQ1I1XiEuSOjgCtWLcADufuivhLarr7m1a0uQWAM0cPE93cJ-Zg4d5UmqsgdQeHTW626_uOBcqbiB07fWHBxO4mHLrZ6JX966-XMmaks8xm5d2j4oXSICyNn3FnyvL4pY7UxfBTqNMdxTeV9-IDsGHWgOVLlcCD_tC4IDMfEK7HumzJVd9Z2QaPwBvpbndh2_3cnz0mhHgIPQe0VNLAbg4xUdb0W7IsjGcJtOfkG3VB9HEFgjSUiRR0tJkqAGH-nj1shfi_X8vJjEpYr3ybaHRB6pqMc9qjvWT2psCB5yf0Icew41GU1_hXSBmIAEsvFENWY',
#  'results': [{'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8581126, 'lng': 2.3529277},
#     'viewport': {'northeast': {'lat': 48.8594393802915,
#       'lng': 2.354352980291503},
#      'southwest': {'lat': 48.8567414197085, 'lng': 2.351655019708499}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Hôtel Duo',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3840,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107554201425443337224">Hôtel Duo</a>'],
#      'photo_reference': 'ATtYBwJehFFNKm3O1fIL-8muQ4MtS2j1TMMPGhJsEVulJTsyE_V6K3VYqlgNq6au9unjz5xLXndHURxP17I3dh61YSATipw55aAG5ZfztVX69GkZBp7jUCEEe7w5YQyOCtiJusuKKYI3dcr-36JESSQW03rkAWMXb501il5Um1HvciIpnbKo',
#      'width': 5760}],
#    'place_id': 'ChIJWU9CqB1u5kcR5P1F2SMoJmc',
#    'plus_code': {'compound_code': 'V953+65 Paris, France',
#     'global_code': '8FW4V953+65'},
#    'rating': 4.2,
#    'reference': 'ChIJWU9CqB1u5kcR5P1F2SMoJmc',
#    'scope': 'GOOGLE',
#    'types': ['night_club',
#     'spa',
#     'lodging',
#     'bar',
#     'gym',
#     'health',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 280,
#    'vicinity': '11 Rue du Temple, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8582861, 'lng': 2.3464944},
#     'viewport': {'northeast': {'lat': 48.8595495802915,
#       'lng': 2.347780980291502},
#      'southwest': {'lat': 48.8568516197085, 'lng': 2.345083019708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Hôtel Britannique - Paris Centre',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1426,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/108984000175492464929">Hôtel Britannique - Paris Centre</a>'],
#      'photo_reference': 'ATtYBwLQ0Smw4sgAWMIB_nRj46564BX9RHKnUcO5Ly33yu1cgkf9EulUZjAPyVQmHaZ2hEelrgQKQsL7oMF2EmmiJkaoiCQdoP0j5ZaBqZIEM-RqH5T5Uo7ZXSE47H5qypr0U7DshQ2ISl0RBt7jmvzN91k6KdJVrBV9dBmr-LJKBwcNcHoh',
#      'width': 1476}],
#    'place_id': 'ChIJ-4Siox9u5kcRm9vM6DcMXyU',
#    'plus_code': {'compound_code': 'V85W+8H Paris, France',
#     'global_code': '8FW4V85W+8H'},
#    'rating': 4.6,
#    'reference': 'ChIJ-4Siox9u5kcRm9vM6DcMXyU',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 483,
#    'vicinity': '20 Avenue Victoria, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8606655, 'lng': 2.3469293},
#     'viewport': {'northeast': {'lat': 48.86176813029151,
#       'lng': 2.348040180291502},
#      'southwest': {'lat': 48.85907016970851, 'lng': 2.345342219708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Citadines Les Halles Paris (Apart Hotel Paris)',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 496,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/102565262508115704337">Citadines Les Halles Paris (Apart Hotel Paris)</a>'],
#      'photo_reference': 'ATtYBwJ2rSJ58coVc5JPHRQ29IHew18M00hAxeH5Rkw19jieeNv2Xax46jsJr8gIPGlCz4zZXC0D5MDO6w_twwjXfWsRom5YAszDY2KWzFKh5AB5eiUfEs2FhgDhbbHIBKLPqTYIoWcsRl0Fh2BUqK-_ZaG1q3SBQRUemhN9PWx7Gj8SxK0i',
#      'width': 745}],
#    'place_id': 'ChIJQ_QDrxhu5kcRJzNxLLEOSfU',
#    'plus_code': {'compound_code': 'V86W+7Q Paris, France',
#     'global_code': '8FW4V86W+7Q'},
#    'rating': 4.1,
#    'reference': 'ChIJQ_QDrxhu5kcRJzNxLLEOSfU',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 815,
#    'vicinity': '4 Rue des Innocents, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8607769, 'lng': 2.3463217},
#     'viewport': {'northeast': {'lat': 48.8620762802915,
#       'lng': 2.347628580291502},
#      'southwest': {'lat': 48.8593783197085, 'lng': 2.344930619708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Novotel Paris Les Halles',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2000,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111815616573299411056">Novotel</a>'],
#      'photo_reference': 'ATtYBwKnQQKET-5citCeiXe72WuospD5P96-Z5fJarxpyFlHJE-3rvRFesv-4OHoQfLMvPoa5b9-MCBqak6BZbNtz4w-8ryBqtnJCrZN2rYsAqjj1X414hDajVd7kz6wC7qbjpsjVEb04fytY5mqxOMPjb-e-aHAvVyMpq3W8T1ruouY9RXG',
#      'width': 3000}],
#    'place_id': 'ChIJGW2pNx9u5kcRI3oyL8NG5BQ',
#    'plus_code': {'compound_code': 'V86W+8G Paris, France',
#     'global_code': '8FW4V86W+8G'},
#    'rating': 4.4,
#    'reference': 'ChIJGW2pNx9u5kcRI3oyL8NG5BQ',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 2095,
#    'vicinity': '8 Place Marguerite de Navarre, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.86034799999999, 'lng': 2.344054},
#     'viewport': {'northeast': {'lat': 48.8616503302915,
#       'lng': 2.345521080291502},
#      'southwest': {'lat': 48.8589523697085, 'lng': 2.342823119708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Hôtel Ducs de Bourgogne',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1390,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/101411638353598558320">Hôtel Ducs de Bourgogne</a>'],
#      'photo_reference': 'ATtYBwIHLbiC5dDEFvkFXmlXEW5Q_ih6IoDuD0-8DTZEbP25IyCisWGLh3-JwTGg8OQ6xN6H5815EqodNPMHqRCfBunX3u-CcvKVAC7RGydAmfFU5i8FHUqW_UYdYdKX1XwO4VZVJxpTivgeSdDyv-SHPkisTx9OpeTLjR5fI2233hdMs1ln',
#      'width': 2048}],
#    'place_id': 'ChIJifTG5yFu5kcRdnisbwxnAx4',
#    'plus_code': {'compound_code': 'V86V+4J Paris, France',
#     'global_code': '8FW4V86V+4J'},
#    'rating': 4.5,
#    'reference': 'ChIJifTG5yFu5kcRdnisbwxnAx4',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 276,
#    'vicinity': '19 Rue du Pont Neuf, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8555091, 'lng': 2.3408736},
#     'viewport': {'northeast': {'lat': 48.8569076302915,
#       'lng': 2.342319280291502},
#      'southwest': {'lat': 48.8542096697085, 'lng': 2.339621319708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Citadines Saint-Germain-des-Prés Paris',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 4480,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113188832595116816387">Citadines Saint-Germain-des-Prés Paris</a>'],
#      'photo_reference': 'ATtYBwJPi63e8XQt-nlPwtG4VE4dVsIIL0vQUXjlwrqdo5FpVlN3aS-mb7iQ5gJrXGB9X6Pdn1S97LTYvP2qvwFE3LRr6Tmltd0jItAJGg5LPWqMslCDNjmqw8S6oSdUnN_U_g930bwewwdk2_43V7oGpzf0gnuea_K-GyU4vhRJ9dNaGvSu',
#      'width': 6720}],
#    'place_id': 'ChIJo5pYcN9x5kcRERXdocMgqmE',
#    'plus_code': {'compound_code': 'V84R+68 Paris, France',
#     'global_code': '8FW4V84R+68'},
#    'rating': 4.3,
#    'reference': 'ChIJo5pYcN9x5kcRERXdocMgqmE',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 660,
#    'vicinity': '53 ter Quai des Grands Augustins, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.86634659999999, 'lng': 2.36064},
#     'viewport': {'northeast': {'lat': 48.86774953029149,
#       'lng': 2.361898330291501},
#      'southwest': {'lat': 48.86505156970849, 'lng': 2.359200369708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Paris France Hôtel',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2673,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/102332962500946068613">Paris France Hôtel</a>'],
#      'photo_reference': 'ATtYBwILdi2_R4cT-6LH93iorvZ70HgfSTqTH50ve97E8pvO_zevs8LIqQtzN2FdCtnK2J7Y9NYta2tGMP8dB2rPjg88BmLA9lXzGBSju3P9jYnqJTiehDmk_WT8BZT3GiVkRCe_1xN8J-5vtR3Vje00RUZ62cUB-YzjeQ_FuSGGlZAyDJgT',
#      'width': 3463}],
#    'place_id': 'ChIJhXWLZg9u5kcRDVyqoZYgcmg',
#    'plus_code': {'compound_code': 'V986+G7 Paris, France',
#     'global_code': '8FW4V986+G7'},
#    'rating': 4.3,
#    'reference': 'ChIJhXWLZg9u5kcRDVyqoZYgcmg',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 378,
#    'vicinity': '72 Rue de Turbigo, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.86386539999999, 'lng': 2.3325488},
#     'viewport': {'northeast': {'lat': 48.8650759802915,
#       'lng': 2.333775730291502},
#      'southwest': {'lat': 48.8623780197085, 'lng': 2.331077769708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Hotel Regina Louvre',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3700,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/109908333790946649027">Hôtel Regina Louvre</a>'],
#      'photo_reference': 'ATtYBwKDsEl3ok7lIbSTCUTCGQsbuFNemiKXunwH6JgAnQV5kmot8rne_xm8gwNC9xrsza9m-akQFanGUb1nWGcNgxmbBGmNSTSrj3gmRNOoigMoB1XT9TiA_r-corWAPODGbhLNdAYqqeujP_h19Fow-ySMFBKIuZ1qLbo07IKUxoO_o2ok',
#      'width': 5550}],
#    'place_id': 'ChIJP_-HCS9u5kcRsj9b1x7Pl8w',
#    'plus_code': {'compound_code': 'V87M+G2 Paris, France',
#     'global_code': '8FW4V87M+G2'},
#    'rating': 4.5,
#    'reference': 'ChIJP_-HCS9u5kcRsj9b1x7Pl8w',
#    'scope': 'GOOGLE',
#    'types': ['lodging',
#     'bar',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 503,
#    'vicinity': '2 Place des Pyramides, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.84795229999999, 'lng': 2.370869},
#     'viewport': {'northeast': {'lat': 48.8492035302915,
#       'lng': 2.372290080291501},
#      'southwest': {'lat': 48.8465055697085, 'lng': 2.369592119708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'ibis Paris Gare de Lyon Ledru Rollin 12ème',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/102166088584622554231">cherry pyj</a>'],
#      'photo_reference': 'ATtYBwJS__3A1XAu75yeAtuf6oCUsrVm_J-HHrQri8LjxCzSmA8AZKwo4oaSAGbH81gQTESRDBgApaCeWwTVb8Kz1dd_h9pXrbwOHYt43cUC8XEKPTVvN_sD6wqFPDho_wVGAr2qYyNzrP0jTH6WoMaEsTv5hXhKHjtjJPAGN7azYkDIMiKQ',
#      'width': 4032}],
#    'place_id': 'ChIJ9RNxcQNy5kcRnZJ4vsuXcow',
#    'plus_code': {'compound_code': 'R9XC+58 Paris, France',
#     'global_code': '8FW4R9XC+58'},
#    'rating': 4,
#    'reference': 'ChIJ9RNxcQNy5kcRnZJ4vsuXcow',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 756,
#    'vicinity': '41/43 Avenue Ledru Rollin, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8710647, 'lng': 2.34991},
#     'viewport': {'northeast': {'lat': 48.87241888029151,
#       'lng': 2.351188530291502},
#      'southwest': {'lat': 48.86972091970851, 'lng': 2.348490569708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Hôtel des Comédies Paris',
#    'photos': [{'height': 683,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/108479076312462330074">Hotels World Online</a>'],
#      'photo_reference': 'ATtYBwKi2138M4A6AaIcBqHUqgb6owOSxOfmJosTDtJX2zRh-GfcLdypaCFARmeheitauVq2_7nMrlmAGfMzL3QpJwbHzWmD_A8iXzMwCMuvYjxfuVgZjh3833E5v9_sKjHTLzjEEEcEy_gQWfxIX0EQsg63-wtZZQDUVmFoNgdPhG6Ycs_b',
#      'width': 1024}],
#    'place_id': 'ChIJn6ginxZu5kcRmAEK0OHm0cI',
#    'plus_code': {'compound_code': 'V8CX+CX Paris, France',
#     'global_code': '8FW4V8CX+CX'},
#    'rating': 4.2,
#    'reference': 'ChIJn6ginxZu5kcRmAEK0OHm0cI',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 194,
#    'vicinity': "8 Rue d'Hauteville, Paris"},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.84754640000001, 'lng': 2.3718722},
#     'viewport': {'northeast': {'lat': 48.8488750302915,
#       'lng': 2.373125480291502},
#      'southwest': {'lat': 48.8461770697085, 'lng': 2.370427519708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Hôtel De France Gare de Lyon Bastille',
#    'photos': [{'height': 787,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/117462031751048846575">Hôtel De France Gare de Lyon Bastille</a>'],
#      'photo_reference': 'ATtYBwKj1SKWJ0nMrdF2ZOptyhcJpoflCnVlwpU0VRTUH9bivk0rR6OyCX0jhkBDTAj4c6EZxDd9pPYfIM0puPBEIQVGnDrkJ3yoHGRLwmpsKiXfNtg-LwUXfLGE51OFaBuSwsLPo4h0RuBuqJNyBFQsB9TQGpl6kQrvSB7rlixen91T2Xj8',
#      'width': 1181}],
#    'place_id': 'ChIJz6DBYgNy5kcRhOu1LhDIECM',
#    'plus_code': {'compound_code': 'R9XC+2P Paris, France',
#     'global_code': '8FW4R9XC+2P'},
#    'rating': 3.3,
#    'reference': 'ChIJz6DBYgNy5kcRhOu1LhDIECM',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 380,
#    'vicinity': '12 Rue de Lyon, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8717386, 'lng': 2.3447052},
#     'viewport': {'northeast': {'lat': 48.8731394302915,
#       'lng': 2.346067130291502},
#      'southwest': {'lat': 48.8704414697085, 'lng': 2.343369169708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Hôtel Prélude Opéra Paris',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1152,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/103624474621674096768">carlos MARTINEZ</a>'],
#      'photo_reference': 'ATtYBwJvKth_YDv05TbtxstpkK4TyRaoF6QBNOifdcf0wPAITKlhwZcabdA1Dib7uc2UBcgLQ-WTDBlQJJDccdTRCtBgfGuRhgjxbSK01qE6968w9DfeZQJ7HYfwGbyAI0sE0GJyP43R03MKAGUp0hAeHdK1Pqvwps77K5Ebwqmv8-kppTgV',
#      'width': 2048}],
#    'place_id': 'ChIJ8e3Qcj5u5kcR2MIGwNxustk',
#    'plus_code': {'compound_code': 'V8CV+MV Paris, France',
#     'global_code': '8FW4V8CV+MV'},
#    'rating': 4.1,
#    'reference': 'ChIJ8e3Qcj5u5kcR2MIGwNxustk',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 328,
#    'vicinity': '8 Cité Bergère, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8423491, 'lng': 2.3632246},
#     'viewport': {'northeast': {'lat': 48.84365908029149,
#       'lng': 2.364711430291502},
#      'southwest': {'lat': 48.8409611197085, 'lng': 2.362013469708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Hôtel Libertel Austerlitz Jardin des Plantes',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 4480,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/114802271282641766772">Hôtel Libertel Austerlitz Jardin des Plantes</a>'],
#      'photo_reference': 'ATtYBwITnCcIJ9y3Iljy19WJzu8B9pFvJsEWlNgFtFZU45t69DKKzn_aMg1lXV-GvJ1NtEFCnvgJWijJLykOkni6r0cQJaP2YNT8nY8zE0SiUSjxiThNeqBe-OySctW5Ocv6GrxCWVEbrMYEK03oeTeYw9qPtGVcEOYziDK32NOmlabdy30d',
#      'width': 6720}],
#    'place_id': 'ChIJe-udXPZx5kcRKURHNFv5BSw',
#    'plus_code': {'compound_code': 'R9R7+W7 Paris, France',
#     'global_code': '8FW4R9R7+W7'},
#    'rating': 4,
#    'reference': 'ChIJe-udXPZx5kcRKURHNFv5BSw',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 433,
#    'vicinity': "12 Boulevard de l'Hôpital, Paris"},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.864294, 'lng': 2.3307997},
#     'viewport': {'northeast': {'lat': 48.8655772302915,
#       'lng': 2.332153880291502},
#      'southwest': {'lat': 48.8628792697085, 'lng': 2.329455919708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Saint James Albany Paris Hôtel Spa',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 650,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/108570400659068256718">Saint James Albany Paris Hôtel Spa</a>'],
#      'photo_reference': 'ATtYBwL6sH3-XNyJfKCiJxWAP_O-LzsW-wmq4FRhiPibcPJq1ibFSeh0_H0XoHHxc-oOEtLKJ34UrJacRv5ZwdHGp9Ms28vXYgQvQvUKveYFno-Z3nan5kwsipNgTwOJciNBdzGoRWsuGcX50pTiC4f-ccQ_QrgfK3zL2EIZI2yhK7mrkJHR',
#      'width': 802}],
#    'place_id': 'ChIJ8znTVS5u5kcREq8TmzOICFs',
#    'plus_code': {'compound_code': 'V87J+P8 Paris, France',
#     'global_code': '8FW4V87J+P8'},
#    'rating': 4,
#    'reference': 'ChIJ8znTVS5u5kcREq8TmzOICFs',
#    'scope': 'GOOGLE',
#    'types': ['lodging',
#     'bar',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 1072,
#    'vicinity': '202 Rue de Rivoli, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.87110329999999, 'lng': 2.3389728},
#     'viewport': {'northeast': {'lat': 48.8724975302915,
#       'lng': 2.340102880291502},
#      'southwest': {'lat': 48.8697995697085, 'lng': 2.337404919708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Hôtel Icône',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1066,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/108137830440312077288">Hôtel Icône</a>'],
#      'photo_reference': 'ATtYBwJYsizZJC2f49G9ucSzSEo6NJU96TlfhPm496yeS8RQgx2_a024Q2BfDir9kHcIi3jGDBtaADp9Y1b-vGq-N0OzZsQPBH9PKGUqvK21mcruTeFnLAFjTwam-EAp9Ei4WWxkVp7nDeFFGbKPFjFp8vIfO4RHfwklQ8rXjIAaqw_kCzpX',
#      'width': 1600}],
#    'place_id': 'ChIJpQvq5Dtu5kcR0COam2f7v_I',
#    'plus_code': {'compound_code': 'V8CQ+CH Paris, France',
#     'global_code': '8FW4V8CQ+CH'},
#    'rating': 3.7,
#    'reference': 'ChIJpQvq5Dtu5kcR0COam2f7v_I',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 135,
#    'vicinity': "4 Rue d'Amboise, Paris"},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8524547, 'lng': 2.3472064},
#     'viewport': {'northeast': {'lat': 48.85380223029149,
#       'lng': 2.348557280291502},
#      'southwest': {'lat': 48.85110426970849, 'lng': 2.345859319708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Hôtel Esmeralda',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1960,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/106443224837840180239">Fraz A. Khan</a>'],
#      'photo_reference': 'ATtYBwLQR9o9wEiJS0bCs2mLHYm_laC0KHxH_0s1bQp8PBHmXmLzGdaMj2ykEaEhnYUEGgqwqdWgyKtpDmf_QtbcpIOZuTld3qTngZkVXT4N__EjqHYwJVtEqZ8yy8BAwD2wPheFO1XpwgSnmk1HYu7-EiAh6xVKnHlQGrXit5ZaJWkPtGWA',
#      'width': 4032}],
#    'place_id': 'ChIJO_g_H-Fx5kcRmaabUHA3dT4',
#    'plus_code': {'compound_code': 'V82W+XV Paris, France',
#     'global_code': '8FW4V82W+XV'},
#    'rating': 4.1,
#    'reference': 'ChIJO_g_H-Fx5kcRmaabUHA3dT4',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 141,
#    'vicinity': '4 Rue Saint-Julien le Pauvre, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8530901, 'lng': 2.3447174},
#     'viewport': {'northeast': {'lat': 48.8544403302915,
#       'lng': 2.346001280291502},
#      'southwest': {'lat': 48.8517423697085, 'lng': 2.343303319708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Albe Hotel',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1152,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/117571951379278191466">Albe Hotel Saint Michel</a>'],
#      'photo_reference': 'ATtYBwJGOssL_K1RVQJdptaZjlBk3sOUBHTlFj_T8KifjSACulpLyoAlgwCC-oXg78S3c5q2hhKhMBiq4qQqrZz0uPW9qTAvx6cgpfh0bpkKw40thGC5fBROKesGYOoMyzdOSxr7zDsEaguyMQM_BjdrO1kzWk1qSkRmQgH8va972jQqSHkj',
#      'width': 1600}],
#    'place_id': 'ChIJ8R5-hOBx5kcRsCOdfj8GLeY',
#    'plus_code': {'compound_code': 'V83V+6V Paris, France',
#     'global_code': '8FW4V83V+6V'},
#    'rating': 4.4,
#    'reference': 'ChIJ8R5-hOBx5kcRsCOdfj8GLeY',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 321,
#    'vicinity': '1 Rue de la Harpe, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8499394, 'lng': 2.3462397},
#     'viewport': {'northeast': {'lat': 48.8513262802915,
#       'lng': 2.347607430291502},
#      'southwest': {'lat': 48.8486283197085, 'lng': 2.344909469708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Home Latin',
#    'photos': [{'height': 606,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/105830788751825835396">Peter Sheehan</a>'],
#      'photo_reference': 'ATtYBwIVvol2PBIf2o17M99ogPJsZ09nwuAk1F73TZEh9IeyjsH_4ARAOXUTSv4L4bLc-TnGeO1nwdSFeRx3bD1uzKPxPfYIBzqITyYB_hb8KSD744i7WqW9Ir267xly6Z9hYZ1ZPEZbw5hykCqHACYCliYUFIeViGymFZrtUjVpsucy69SY',
#      'width': 1080}],
#    'place_id': 'ChIJMWNDIudx5kcRupjNdNDYKkw',
#    'plus_code': {'compound_code': 'R8XW+XF Paris, France',
#     'global_code': '8FW4R8XW+XF'},
#    'rating': 3.6,
#    'reference': 'ChIJMWNDIudx5kcRupjNdNDYKkw',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 264,
#    'vicinity': '15-17 Rue du Sommerard, Paris'},
#   {'business_status': 'CLOSED_TEMPORARILY',
#    'geometry': {'location': {'lat': 48.85473870000001, 'lng': 2.3395455},
#     'viewport': {'northeast': {'lat': 48.8561127802915,
#       'lng': 2.340820530291502},
#      'southwest': {'lat': 48.8534148197085, 'lng': 2.338122569708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': "Hôtel d'Aubusson",
#    'permanently_closed': True,
#    'photos': [{'height': 2174,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/115702439863948549296">Hôtel d&#39;Aubusson Paris</a>'],
#      'photo_reference': 'ATtYBwL3bYjs5PDwHc3DEtGlvTIw1WsXSaRbI0tI7EkO8VlSBMKcidgKYfSrQi8_n5OwfXCOo5hOajZfl9WWhtsfGRfAaFNRO_iDyoopUj0FqIKwr2rY1fBHtUiRtaptHxpysX3LHHZ3FdTh_BSpK6tWB700DBVO949MQENvZLOXwOkSCoF3',
#      'width': 1739}],
#    'place_id': 'ChIJk6ztMN9x5kcREpQ8edWOs7E',
#    'plus_code': {'compound_code': 'V83Q+VR Paris, France',
#     'global_code': '8FW4V83Q+VR'},
#    'rating': 4.7,
#    'reference': 'ChIJk6ztMN9x5kcREpQ8edWOs7E',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 275,
#    'vicinity': '33 Rue Dauphine, Paris'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.85184049999999, 'lng': 2.3448082},
#     'viewport': {'northeast': {'lat': 48.85313113029149,
#       'lng': 2.346144730291502},
#      'southwest': {'lat': 48.8504331697085, 'lng': 2.343446769708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Hôtel 4 étoiles Parc Saint Séverin Paris 5ème - Esprit de France',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2362,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107542132357877294567">Hôtel 4 étoiles Parc Saint Séverin Paris 5ème - Esprit de France</a>'],
#      'photo_reference': 'ATtYBwK7vSFJQ_FygzmoDkixtTH8NNqULdmKvKV4_x35FJKv0kREbxb23W6296mfWjghRnMV04yQ4OkRcIqEVVk34Ju8WWJzAE_WhoEuAHqurdDlp2xYSxF3P_tVhcYs3F2B2TcFBDe4Xt3Gdn637zS26SKGgs9X-eFPg6WUs7f-s1aJaCn5',
#      'width': 3776}],
#    'place_id': 'ChIJ9--kuuBx5kcRojwQ1yEK2cY',
#    'plus_code': {'compound_code': 'V82V+PW Paris, France',
#     'global_code': '8FW4V82V+PW'},
#    'rating': 4.6,
#    'reference': 'ChIJ9--kuuBx5kcRojwQ1yEK2cY',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 139,
#    'vicinity': '22 Rue de la Parcheminerie, Paris'}],
#  'status': 'OK'}

# %%
len(hotels["results"])
# Out:
# 20

# %%
# Iterate through the DataFrame.
for index, row in hotel_df.iterrows():
    # Get the latitude and longitude.
    lat = row["Lat"]
    lng = row["Lng"]

    # Add the latitude and longitude to location key for the params dictionary.
    params["location"] = f"{lat},{lng}"

    # Use the search term: "lodging" and our latitude and longitude.
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    # Make request and get the JSON data from the search.
    hotels = requests.get(base_url, params=params).json()

    # Grab the first hotel from the results and store the name.
try:
 hotel_df.loc[index, "Hotel Name"] = hotels["results"][0]["name"]
except (IndexError):
 print("Hotel not found... skipping.")

hotels
# Out:
# {'html_attributions': [],
#  'next_page_token': 'ATtYBwKjea2oMActFbVUNM-2Lu3rAfzmPunKHviModhGrmlkLUSVlkvQvGBq4o054wIQne72CBxu9C_yVgd_H9kg9wT0WnkaQaGOqlukqMlVG4kuKCjRDjjBi5AsoM-x856GEdOOxbkN3exK4oHeq50Y8-bj8lJez2TXjPWbJ6ljWxxZqD5FV3Muk2jTPMZb2vYwC5qluflzrF1Ahn_ay4MQwhDS9JI6tWC0N8KlBo6UapsF2vQHRa6qDN0jNpnT5TP5lm6cfpfV22LEyLSY8XtrWCPnD75BFiKC_rZyBF9kAqPP4BjtvkT-ugXcRkyAcZWmSAHQyGSIyb3KDxyvVAwXX-G2hG_2bTXoUvHTEWHepMX6A_XmKdsyMaECP8r73MWsyszcyg02nzBkxr6eZ9tu7dZnOGZaoBYvf5Uv-NdyqrjsF4IMWDbUaXw8',
#  'results': [{'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 29.4242727, 'lng': -98.492007},
#     'viewport': {'northeast': {'lat': 29.4258049802915,
#       'lng': -98.4904800697085},
#      'southwest': {'lat': 29.4231070197085, 'lng': -98.4931780302915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Drury Plaza Hotel San Antonio Riverwalk',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 4000,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/101578688962638790736">Drury Plaza Hotel San Antonio Riverwalk</a>'],
#      'photo_reference': 'ATtYBwIaAqomcCUhnLoViJ6iSKAyE4mkrUDHfAxH70ud2jvlX3r5naBMnXTzu8K3bJVuxjPhcX7AdwoDtkQg8Er5P0l7BSkkwwNYBGKu4sluS2Ps1Wm8YbCYLH6DffbvgnyxhKrxO7_EBQBDn9NVRQMzJhLTDke8zYA78QZu2Ndxzc-2rSey',
#      'width': 6000}],
#    'place_id': 'ChIJOeCvNFNfXIYRn11BEYC6Eck',
#    'plus_code': {'compound_code': 'CGF5+P5 San Antonio, TX, USA',
#     'global_code': '76X3CGF5+P5'},
#    'rating': 4.5,
#    'reference': 'ChIJOeCvNFNfXIYRn11BEYC6Eck',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 2672,
#    'vicinity': "105 South Saint Mary's Street, San Antonio"},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 29.4227669, 'lng': -98.49303599999999},
#     'viewport': {'northeast': {'lat': 29.4242803802915,
#       'lng': -98.49177631970849},
#      'southwest': {'lat': 29.4215824197085, 'lng': -98.49447428029151}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Riverwalk Plaza Hotel',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/109635693452035690146">Riverwalk Plaza Hotel</a>'],
#      'photo_reference': 'ATtYBwJJEGeNmLk2e1cNBbXwl61UwL5DDsNEkJoPaG_Y75Plzd7XQrxo7eAM-tPMPJJklcdtyf-N8wGqUnksxNCYiYsnBGDB2cRvR7LTeAEfDNaPl6SGoA9mMFSQDfI02vZe4i_EdbWmTp1Uab24eToMLAFDyuCBsfsKQATUS8rqKZhW42-5',
#      'width': 1600}],
#    'place_id': 'ChIJnRWhBa1YXIYReQg4LVjL85w',
#    'plus_code': {'compound_code': 'CGF4+4Q San Antonio, TX, USA',
#     'global_code': '76X3CGF4+4Q'},
#    'rating': 4,
#    'reference': 'ChIJnRWhBa1YXIYReQg4LVjL85w',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 1510,
#    'vicinity': '100 Villita Street, San Antonio'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 29.4236049, 'lng': -98.49158469999999},
#     'viewport': {'northeast': {'lat': 29.4250758802915,
#       'lng': -98.49023481970849},
#      'southwest': {'lat': 29.4223779197085, 'lng': -98.49293278029151}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Homewood Suites by Hilton San Antonio-Riverwalk/Downtown',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 9000,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113550399298695653079">Rob Mccray</a>'],
#      'photo_reference': 'ATtYBwIDbXnyBZfJQJsJbdkhYKHf1_rHLeIItmGLRKGGFNr8MSZC-zigaBTOxyQ3YB3xdViy_7Wtrbr6etngNrT5PwiqRDUq4zsOEbR4awmmw4HtGzJh4CsFeSw7rGr0vF2sQwR_K4g27jXTcB413DoGP0yzDI0IesG_RTn8klfdHHvRf2BL',
#      'width': 12000}],
#    'place_id': 'ChIJBbjLwaxYXIYRbkuokPaua84',
#    'plus_code': {'compound_code': 'CGF5+C9 San Antonio, TX, USA',
#     'global_code': '76X3CGF5+C9'},
#    'rating': 4.3,
#    'reference': 'ChIJBbjLwaxYXIYRbkuokPaua84',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 760,
#    'vicinity': '432 West Market Street, San Antonio'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 29.42534749999999, 'lng': -98.4918018},
#     'viewport': {'northeast': {'lat': 29.4266043302915,
#       'lng': -98.49022401970849},
#      'southwest': {'lat': 29.4239063697085, 'lng': -98.49292198029151}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Drury Inn & Suites San Antonio Riverwalk',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3695,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/106949387413214353679">Drury Inn &amp; Suites San Antonio Riverwalk</a>'],
#      'photo_reference': 'ATtYBwLLhEYAIFM7-IQIY6POaa-8YUD6LHNa4rR_EYjLF3ovJBAsuPuJ2SATvbPdgKnD3yJFNKr6ys9jbDrSNAba3Z_3Os2RvpzZUBeHXRIs5J2J2XaNOZ0O5XAgSA2THlCUZqYY5nn9uHnJRXa0iWzY7EvDSLoaUBrOesCcgZrlT-fzMZOK',
#      'width': 5540}],
#    'place_id': 'ChIJOeCvNFNfXIYRP2icQaL6xbI',
#    'plus_code': {'compound_code': 'CGG5+47 San Antonio, TX, USA',
#     'global_code': '76X3CGG5+47'},
#    'rating': 4.5,
#    'reference': 'ChIJOeCvNFNfXIYRP2icQaL6xbI',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 1173,
#    'vicinity': "201 North Saint Mary's Street, San Antonio"},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 29.4255527, 'lng': -98.49164830000001},
#     'viewport': {'northeast': {'lat': 29.4268608302915,
#       'lng': -98.4901468697085},
#      'southwest': {'lat': 29.4241628697085, 'lng': -98.49284483029152}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Courtyard by Marriott San Antonio Riverwalk',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 809,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111140291022097228754">Courtyard by Marriott San Antonio Riverwalk</a>'],
#      'photo_reference': 'ATtYBwJeCr6_Ip-n14Pr3n4Im37rX9MNYp3CgFW5LRsleNlgJ9yc62fQQ7bgmCxrcxXkQcC0T_5JUKB1gaYRy0VMvenzxJe-cCiQUUB2hmnS9hwf098fWEk2YQ220_DnGUWDrBQcJ4bWxVoG34-4kGwm2AMN37FzIcGJUyNATB139aEeXUpb',
#      'width': 1439}],
#    'place_id': 'ChIJdQr0LVNfXIYRYnCNLQwakmM',
#    'plus_code': {'compound_code': 'CGG5+68 San Antonio, TX, USA',
#     'global_code': '76X3CGG5+68'},
#    'rating': 4.2,
#    'reference': 'ChIJdQr0LVNfXIYRYnCNLQwakmM',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 1017,
#    'vicinity': "207 North Saint Mary's Street, San Antonio"},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 29.4256922, 'lng': -98.4917403},
#     'viewport': {'northeast': {'lat': 29.42719548029149,
#       'lng': -98.4901909197085},
#      'southwest': {'lat': 29.4244975197085, 'lng': -98.4928888802915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Holiday Inn San Antonio-Riverwalk',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2160,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/104040191252143205291">C Wojcik</a>'],
#      'photo_reference': 'ATtYBwKtEcfieQ5Oilpy-E067bmiu6r8yzyRn420eDbE2SrEL_CiApcLCJ26RuWFnKUvDX_0POxs8SSFci3E6rwqKI5T_cpCAhT7KCY8gkUEGF0EGLR6APabWxhoubxLP-oavkUlOvI2VTWwX1GDbmAyfN9UXQ6hAKV1L_gxmlQCz5EYaKEt',
#      'width': 3840}],
#    'place_id': 'ChIJ0ckEN1NfXIYR-FRNR83whFY',
#    'plus_code': {'compound_code': 'CGG5+78 San Antonio, TX, USA',
#     'global_code': '76X3CGG5+78'},
#    'rating': 4.2,
#    'reference': 'ChIJ0ckEN1NfXIYR-FRNR83whFY',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 1782,
#    'vicinity': "217 North Saint Mary's Street, San Antonio"},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 29.4259381, 'lng': -98.49552299999999},
#     'viewport': {'northeast': {'lat': 29.4272788802915,
#       'lng': -98.4943729697085},
#      'southwest': {'lat': 29.4245809197085, 'lng': -98.4970709302915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Holiday Inn Express San Antonio N-Riverwalk Area',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3000,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/109033583461802199950">Pearl Wang</a>'],
#      'photo_reference': 'ATtYBwI1-rUKebdwLmNiu1LT58CBN4IpVsKbmmSgBlwhNTk3tcTABfIY-89LzFc9ZigQj_dPKxaqrOK5f0R0_s_uQxii7uffyfCgsUh_cHNE_D3RyGoZVv4fS3wYxP4Hp9D4Gd3eQv5LKE6Qtb9XFc3QMLmucMXytmnbJB-i1A8oO32v53Op',
#      'width': 5332}],
#    'place_id': 'ChIJGebCWk1fXIYRg-duPiHHppE',
#    'plus_code': {'compound_code': 'CGG3+9Q San Antonio, TX, USA',
#     'global_code': '76X3CGG3+9Q'},
#    'rating': 3.5,
#    'reference': 'ChIJGebCWk1fXIYRg-duPiHHppE',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 772,
#    'vicinity': '120 Camaron Street, San Antonio'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 29.426571, 'lng': -98.4929147},
#     'viewport': {'northeast': {'lat': 29.4279574802915,
#       'lng': -98.4917070697085},
#      'southwest': {'lat': 29.4252595197085, 'lng': -98.4944050302915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Embassy Suites by Hilton San Antonio Riverwalk Downtown',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 5304,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/101723335792248432426">Embassy Suites by Hilton San Antonio Riverwalk Downtown</a>'],
#      'photo_reference': 'ATtYBwLvZzRiHlCLDZjl4K3H1Yu-hYPZoxO3O9HIVJwwMYXlSQb-pMEkyMZus5SU702VrnEhz967SAhzno_cxNkJ2ckuga3a4J-7n7-wlleGgihIjjLaPDHnEWxf2mPItpkOlPDfAHpZFiK555HmE61VyyMCgn-pZGQD-53jMbsWB7sfhn4',
#      'width': 7952}],
#    'place_id': 'ChIJKYi55lJfXIYRl9YV_3w3R1c',
#    'plus_code': {'compound_code': 'CGG4+JR San Antonio, TX, USA',
#     'global_code': '76X3CGG4+JR'},
#    'rating': 4.4,
#    'reference': 'ChIJKYi55lJfXIYRl9YV_3w3R1c',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 2110,
#    'vicinity': '125 East Houston Street, San Antonio'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 29.4234017, 'lng': -98.4907714},
#     'viewport': {'northeast': {'lat': 29.4248851802915,
#       'lng': -98.48937791970849},
#      'southwest': {'lat': 29.4221872197085, 'lng': -98.4920758802915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'The Westin Riverwalk, San Antonio',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1366,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/106121510922927903968">The Westin Riverwalk, San Antonio</a>'],
#      'photo_reference': 'ATtYBwJ82CVp0zQV_jVMPYfOqypX3PKOB4mldz1M0eF0Dq0PareQHJypF8J7gvrQhC4sjnflHsyQdhquPiCoOhZ_wsOr3LK7JsvN9q3fzXUgJSlHIl7DRrwVhzWF5wfM3rUVjPBvhu5VeLRjDfeQ8gniCWUtaNkAjUPoEW50kA3NwRLEU7Ly',
#      'width': 2048}],
#    'place_id': 'ChIJMeDgmaxYXIYRcG_LOHS5ooc',
#    'plus_code': {'compound_code': 'CGF5+9M San Antonio, TX, USA',
#     'global_code': '76X3CGF5+9M'},
#    'rating': 4.4,
#    'reference': 'ChIJMeDgmaxYXIYRcG_LOHS5ooc',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 2742,
#    'vicinity': '420 West Market Street, San Antonio'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 29.4262737, 'lng': -98.4915927},
#     'viewport': {'northeast': {'lat': 29.4277239302915,
#       'lng': -98.4902437197085},
#      'southwest': {'lat': 29.4250259697085, 'lng': -98.49294168029151}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Hotel Valencia Riverwalk',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2191,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/115662169059546932272">Hotel Valencia Riverwalk</a>'],
#      'photo_reference': 'ATtYBwLByWOupMrwBveMt6-5w1dMpJlHPjt5MhBsNn_RK4PoUdslo0uiIoYD8oWLv_DUPS1a7we_tZxVh3POyVcwuW65xsF_ybxvFihsfsRoX_uiaYKGMO4H0jVZDVOMCkXhaTxcbMzbvmEG9B3hkr0aANIGeueETgeok4lP4UE-jrmpK07Y',
#      'width': 3900}],
#    'place_id': 'ChIJyZ4wO1NfXIYRtsq64dVgkjE',
#    'plus_code': {'compound_code': 'CGG5+G9 San Antonio, TX, USA',
#     'global_code': '76X3CGG5+G9'},
#    'rating': 4.4,
#    'reference': 'ChIJyZ4wO1NfXIYRtsq64dVgkjE',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 2077,
#    'vicinity': '150 East Houston Street, San Antonio'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 29.425762, 'lng': -98.49038999999999},
#     'viewport': {'northeast': {'lat': 29.42716113029149,
#       'lng': -98.48904071970848},
#      'southwest': {'lat': 29.4244631697085, 'lng': -98.49173868029149}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Omni La Mansión del Rio RiverWalk',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 660,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/105630260487743266918">Omni La Mansión del Rio RiverWalk</a>'],
#      'photo_reference': 'ATtYBwLh7cmZ5sAd4N1A13FLrmFeUff2iwnUtr157FR7fmDgaL4CUUhHzPCSLMmywfQuxdbucTAqpgDRFWAvN-o7u7QCovBQhlKu9_XGi40Ut5b-8gfy3v5tj1mvPqHDklP0VyuP64MGQG-MRK3b0k9lB3g7GgKmesQy1Yt9n_XNtqDrLM7W',
#      'width': 1170}],
#    'place_id': 'ChIJK8UsNlNfXIYRIqeTmH26wyw',
#    'plus_code': {'compound_code': 'CGG5+8R San Antonio, TX, USA',
#     'global_code': '76X3CGG5+8R'},
#    'rating': 4.4,
#    'reference': 'ChIJK8UsNlNfXIYRIqeTmH26wyw',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 2615,
#    'vicinity': '112 College Street, San Antonio'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 29.4268112, 'lng': -98.49105720000001},
#     'viewport': {'northeast': {'lat': 29.4281358802915,
#       'lng': -98.4898491697085},
#      'southwest': {'lat': 29.4254379197085, 'lng': -98.49254713029151}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Sheraton Gunter Hotel San Antonio',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1366,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/114707578270341819855">Sheraton Gunter Hotel San Antonio</a>'],
#      'photo_reference': 'ATtYBwI-5rgISgT7R5VtP-jbNdt8xPuKDA4uZBTHLteBSZbs6SisvF3Mkp2NAYS2LyAg6oFVS_htQ2xk3cq3LMhVdfw3OxEWDBtWnxXm9xEX9WWMmvw2KVls-QAuVJNLiVE6Q8tHOFcKbep9qRAzqhkz6OrdjydB8QwgBHutkAU2xZmk5WZa',
#      'width': 2048}],
#    'place_id': 'ChIJw6rxPlNfXIYRu43Z7ntBuIE',
#    'plus_code': {'compound_code': 'CGG5+PH San Antonio, TX, USA',
#     'global_code': '76X3CGG5+PH'},
#    'rating': 4.1,
#    'reference': 'ChIJw6rxPlNfXIYRu43Z7ntBuIE',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 1798,
#    'vicinity': '205 East Houston Street, San Antonio'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 29.4268344, 'lng': -98.48995130000002},
#     'viewport': {'northeast': {'lat': 29.4281593302915,
#       'lng': -98.48850726970849},
#      'southwest': {'lat': 29.4254613697085, 'lng': -98.49120523029151}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Home2 Suites by Hilton San Antonio Downtown - Riverwalk, TX',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 853,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111797662989860877570">Home2 Suites</a>'],
#      'photo_reference': 'ATtYBwJj_SLc9_F16Xv1Q0ub-lXkV_nUp-7SGbSFr3aJgnvqf5MtIo6ksd95XHSyrwOItivfebux_G2HEijyvLkECch6y6K6qWHLqD9NrGYN6Su9S7NFRQnF7JVM92OZNxemv56Nt54a4-O7dBo2pRMdZ8vtJrVYjVoowTBX_JnPmaz51EaN',
#      'width': 1280}],
#    'place_id': 'ChIJzdgqXlNfXIYRWr9JRAcdmIs',
#    'plus_code': {'compound_code': 'CGG6+P2 San Antonio, TX, USA',
#     'global_code': '76X3CGG6+P2'},
#    'rating': 4,
#    'reference': 'ChIJzdgqXlNfXIYRWr9JRAcdmIs',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 854,
#    'vicinity': '603 Navarro Street, San Antonio'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 29.41959779999999, 'lng': -98.4919212},
#     'viewport': {'northeast': {'lat': 29.42096473029149,
#       'lng': -98.49040601970849},
#      'southwest': {'lat': 29.4182667697085, 'lng': -98.49310398029151}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Hyatt Place San Antonio/Riverwalk',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1536,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/112877801991048673816">Andrew Ibarra</a>'],
#      'photo_reference': 'ATtYBwI6H9Oc3H81xBiLwycHiPPEHCYkzVA9773sme8MmXVz8fpogJ_fGmyRaVtjuby7ediJzG2fJdLzeZu0v0580HymjrR7J6UerV7hJh88F7LMVn7Ezck_TzAJkQRgQHLinx_bj3yFxWpbdTBeVy-z5T4JRkag53RjJyEoatC7bP8VhdJh',
#      'width': 2048}],
#    'place_id': 'ChIJ9eBoJ6xYXIYRLu83h_2E8HE',
#    'plus_code': {'compound_code': 'CG95+R6 San Antonio, TX, USA',
#     'global_code': '76X3CG95+R6'},
#    'rating': 4.3,
#    'reference': 'ChIJ9eBoJ6xYXIYRLu83h_2E8HE',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 1028,
#    'vicinity': "601 South Saint Mary's Street, San Antonio"},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 29.42737159999999,
#      'lng': -98.48915319999999},
#     'viewport': {'northeast': {'lat': 29.4287927802915,
#       'lng': -98.48810646970848},
#      'southwest': {'lat': 29.4260948197085, 'lng': -98.49080443029149}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'The St. Anthony, a Luxury Collection Hotel, San Antonio',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1366,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/110880875940296284644">The St. Anthony, a Luxury Collection Hotel, San Antonio</a>'],
#      'photo_reference': 'ATtYBwI6jTu2RF4pvRXSoWL5sKpH1oa5_vmCn0PdK3h0eBNiIxKT013bUiqEp5MYwMjtpp4iWflkdsPPrH2ps2VzJngks1JEEu9gibT71028xObjrrnE2yrwqLleWIo0NFmmtUx0QiEhlaKLlkIpK9xL3WIgouDKVRNRXgvDPF9f49jEn7eX',
#      'width': 2048}],
#    'place_id': 'ChIJYZ1VfVNfXIYRBPzhpCTxRgI',
#    'plus_code': {'compound_code': 'CGG6+W8 San Antonio, TX, USA',
#     'global_code': '76X3CGG6+W8'},
#    'rating': 4.5,
#    'reference': 'ChIJYZ1VfVNfXIYRBPzhpCTxRgI',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 1586,
#    'vicinity': '300 East Travis Street, San Antonio'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 29.4258275, 'lng': -98.48807180000001},
#     'viewport': {'northeast': {'lat': 29.4270406302915,
#       'lng': -98.48663421970849},
#      'southwest': {'lat': 29.4243426697085, 'lng': -98.48933218029151}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Hyatt Regency San Antonio Riverwalk',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2668,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/103590530086654700084">Hyatt Regency San Antonio Riverwalk</a>'],
#      'photo_reference': 'ATtYBwKVJJ8p9PrsA0EwQANeFRifBt9nboPeNky_xuLhJpNGGXLmxNetmWEzXHI2M__sSFf-SftFtDzkHtFx4cKM_06A8EC71v-NCQZU6IEPmb-9yuLN-8HMGMVAAq_mx1bhnrO3Ievc3QzB_ir4cQI749iAP-deYNMwUmzXCVRfdFUsJhTd',
#      'width': 4002}],
#    'place_id': 'ChIJIUZeM6tYXIYR9bubfrWnKjQ',
#    'plus_code': {'compound_code': 'CGG6+8Q San Antonio, TX, USA',
#     'global_code': '76X3CGG6+8Q'},
#    'rating': 4.5,
#    'reference': 'ChIJIUZeM6tYXIYR9bubfrWnKjQ',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 4985,
#    'vicinity': '123 Losoya Street, San Antonio'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 29.4223437, 'lng': -98.48791179999999},
#     'viewport': {'northeast': {'lat': 29.4236206802915,
#       'lng': -98.4863881197085},
#      'southwest': {'lat': 29.4209227197085, 'lng': -98.4890860802915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Hilton Palacio del Rio',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/117290988567304195345">Hilton Palacio del Rio</a>'],
#      'photo_reference': 'ATtYBwKv7-RhwVPeY1TxQt6mS7-b3WMzNvpO2IJ5_yzdNQqajgxZYkM4Tr7-GVw3stuv5NkX53w83OHxNQeiRQ1ur0HFyh1vVxPYHgNtx8w3M8W141ohWDeA8YGlfrPIhTIXomsvwIe9xFpRKeExHSXgwVS-2JoiKp9xvave8lNGdvm7dKr9',
#      'width': 4032}],
#    'place_id': 'ChIJ_Y1_CKtYXIYRtDLl_s-EUqg',
#    'plus_code': {'compound_code': 'CGC6+WR San Antonio, TX, USA',
#     'global_code': '76X3CGC6+WR'},
#    'rating': 4.4,
#    'reference': 'ChIJ_Y1_CKtYXIYRtDLl_s-EUqg',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 3019,
#    'vicinity': '200 South Alamo Street, San Antonio'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 29.4240439, 'lng': -98.4998111},
#     'viewport': {'northeast': {'lat': 29.4255526302915,
#       'lng': -98.4985897197085},
#      'southwest': {'lat': 29.4228546697085, 'lng': -98.50128768029151}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'La Quinta Inn by Wyndham San Antonio Market Square',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 400,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/110037818394525569270">La Quinta Inn by Wyndham San Antonio Market Square</a>'],
#      'photo_reference': 'ATtYBwLArhyWjPQM4kOcaeL54eIEjOQp-L0JdZOhLnaEOa-TNgB9pDncwL0YqJOX5XraRTfjU3DZLWvYC06u8ip321jG0E4fgfZQYo50-cljoA_BOBV_miizDm-gpkLqFdzpPiZoN_Swa5S7AS4spmMdkuy2RpR3GtEVJkIMvEx-epYjovyN',
#      'width': 600}],
#    'place_id': 'ChIJpYCPRbNYXIYRPOKWTfTyfIQ',
#    'plus_code': {'compound_code': 'CGF2+J3 San Antonio, TX, USA',
#     'global_code': '76X3CGF2+J3'},
#    'rating': 3.8,
#    'reference': 'ChIJpYCPRbNYXIYRPOKWTfTyfIQ',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 980,
#    'vicinity': '900 Dolorosa, San Antonio'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 29.4266837, 'lng': -98.48815069999999},
#     'viewport': {'northeast': {'lat': 29.4279701802915,
#       'lng': -98.48672131970848},
#      'southwest': {'lat': 29.4252722197085, 'lng': -98.4894192802915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'TownePlace Suites by Marriott San Antonio Downtown',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1366,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/114214920074327902794">TownePlace Suites by Marriott San Antonio Downtown</a>'],
#      'photo_reference': 'ATtYBwK8bLokcNxVtypX8pq7QidrEvrClDLyNIAX29zVIuv71jzz6O9r43BFse-MIh1weDeuPmfavl_6cRGodo_iqEIiET0EkaAeGPr1T7pDnxyjRbADzJ_fyngBTkmwYoZPfyeMDiWJyJmvSJ8FgeC3MiY1NDjAWdtK9aG8RLbQI2ibavJG',
#      'width': 2048}],
#    'place_id': 'ChIJK4S4wVRfXIYRavEaRoab5uk',
#    'plus_code': {'compound_code': 'CGG6+MP San Antonio, TX, USA',
#     'global_code': '76X3CGG6+MP'},
#    'rating': 3.9,
#    'reference': 'ChIJK4S4wVRfXIYRavEaRoab5uk',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 686,
#    'vicinity': '409 East Houston Street, San Antonio'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 29.4200749, 'lng': -98.4984324},
#     'viewport': {'northeast': {'lat': 29.4215778802915,
#       'lng': -98.49727291970848},
#      'southwest': {'lat': 29.4188799197085, 'lng': -98.4999708802915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Courtyard by Marriott San Antonio Downtown/Market Square',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1366,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/110612198932185398498">Courtyard by Marriott San Antonio Downtown/Market Square</a>'],
#      'photo_reference': 'ATtYBwKwu12WieKqeUM_yQxodFx0Ozhtkm8h2F0feldonjPzlk9X9mpPh5pXN65li74FallneCVacfNhXLnT0G1P5W6FFXDcgdAQJJTxcMJkQ1uI5a3roAVYnzt-lTj6btFjkMU4jZ2HVPEFa7eRk7RKXaA4vWmvw3NQkkagnPMluyuuxWaW',
#      'width': 2048}],
#    'place_id': 'ChIJG1w9v7NYXIYRYexTDQI_ku4',
#    'plus_code': {'compound_code': 'CGC2+2J San Antonio, TX, USA',
#     'global_code': '76X3CGC2+2J'},
#    'rating': 4.2,
#    'reference': 'ChIJG1w9v7NYXIYRYexTDQI_ku4',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 752,
#    'vicinity': '600 South Santa Rosa Avenue, San Antonio'}],
#  'status': 'OK'}

# %%
# Add a heatmap of temperature for the vacation spots and marker for each city.
locations = hotel_df[["Lat", "Lng"]]
max_temp = hotel_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=2.0)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp,
             dissipating=False, max_intensity=300, point_radius=4)
marker_layer = gmaps.marker_layer(locations)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""
# Store the DataFrame Row.
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]

# %%
# Add a heatmap of temperature for the vacation spots and a pop-up marker for each city.
locations = hotel_df[["Lat", "Lng"]]
max_temp = hotel_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=2.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp,dissipating=False,
             max_intensity=300, point_radius=4)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)

# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
